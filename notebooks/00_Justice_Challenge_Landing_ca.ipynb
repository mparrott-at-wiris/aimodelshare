# %% [markdown]
# <div style="text-align:center; margin-top:40px;">
#   <h1 style="font-size:2.6em; font-weight:700; margin-bottom:0.4em;">Ètica en Joc</h1>
#
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     Welcome to Ètica en Joc! Experimentaràs com la intel·ligència artificial pot afectar decisions del món real. Through immersive, gamified scenarios, you’ll take on roles, make choices, and see the consequences of AI in action—no technical background required.
#   </p>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     Les teves accions seran guiades per la Brúixola Moral, desenvolupada amb experts de l'Observatori Català d'Ètica en Intel·ligència Artificial (OEIAC) de la UdG per mesurar com d'ètiques són les teves solucions d'IA.
#   </p>
#
#   <h2 style="font-size:2.0em; font-weight:600; margin-top:1.5em; color:#444;">You’ll tackle three challenges:</h2>
#   <ul style="font-size:1.2em; line-height:1.6; max-width:680px; margin:20px auto; text-align:left; list-style-position: inside;">
#     <li><strong>Justícia i Equitat</strong> – Identifica el biaix i aprèn com corregir-lo en models d'IA.</li>
#     <li><strong>Transparència i Explicabilitat</strong> – Fes que les decisions d'IA siguin comprensibles i responsables. (Pròximament)</li>
#     <li><strong>Sostenibilitat</strong> – Equilibra l'impacte ambiental, la privacitat i la supervisió humana per crear IA responsable. (Pròximament)</li>
#   </ul>
#
#   <p style="font-size:1.0em; color:#555; max-width:700px; margin:30px auto 30px;">
#     Programa coordinat per Edutech Cluster, amb el suport de la Generalitat de Catalunya.
#   </p>
#
#   <hr style="margin:50px auto; max-width:640px;">
#
#   <h2 style="font-size:2.0em; font-weight:600; margin-top:0; color:#444;">Justícia i Equitat Challenge</h2>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     This is the flagship module of the Ètica en Joc program. El nostre objectiu és sensibilitzar sobre els riscos ètics de la Intel·ligència Artificial, no a través de teoria abstracta, sinó a través d'una experiència d'aprenentatge pràctic.
#   </p>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     En aquest repte, tu:
#   </p>
#   <ul style="font-size:1.2em; line-height:1.6; max-width:680px; margin:20px auto; text-align:left; list-style-position: inside;">
#     <li>Assumiràs rols del món real, com un jutge que utilitza recomanacions d'IA i un enginyer d'IA que construeix un nou model.</li>
#     <li>Interactuaràs amb un escenari gamificat basat en una IA del món real utilitzada per predir el risc criminal.</li>
#     <li>Descobriràs com centrar-se només en la precisió tècnica pot crear resultats injustos i esbiaixats.</li>
#     <li>Aprendràs a identificar, mesurar i corregir el biaix de l'IA utilitzant un marc ètic expert.</li>
#   </ul>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     L'experiència completa requereix aproximadament entre 1 i 1,5 hores per completar-se. Al final, rebràs un certificat d'educació digital per reconèixer les teves noves habilitats.
#   </p>
#
#   <hr style="margin:50px auto; max-width:640px;">
#
#   <div style="margin:50px 0;">
#     <a href="https://colab.research.google.com/github/mparrott-at-wiris/aimodelshare/blob/master/notebooks/Etica_en_Joc_Justice_Challenge.ipynb" target="_blank" style="text-decoration:none;">
#       <div style="display:inline-block; background:#2962FF; color:#fff; padding:28px 46px; border-radius:14px; font-size:2.0em; font-weight:700; box-shadow:0 6px 18px rgba(0,0,0,0.25);">
#         ▶ Start the Justícia i Equitat Challenge
#       </div>
#     </a>
#   </div>
#   <p style="font-size:1.05em; color:#555; max-width:700px; margin:0 auto 40px;">
#     Després de fer clic, s'obrirà una nova pestanya del navegador a Google Colab. Si apareix un avís, tria <em>“Executar igualment”</em>. Després segueix els passos simples que es mostren allà.
#   </p>
#   <hr style="margin:50px auto; max-width:640px;">
#   <p style="font-size:0.95em; color:#666; max-width:680px; margin:0 auto 60px;">
#     Si el botó no funciona, copia i enganxa aquest enllaç al teu navegador:<br>
#     <code>https://colab.research.google.com/github/mparrott-at-wiris/aimodelshare/blob/master/notebooks/Etica_en_Joc_Justice_Challenge.ipynb</code>
#   </p>
# </div>

# %% [markdown]
# ### Accessibilitat / Text per a lectors de pantalla
# Utilitza la navegació per encapçalaments per arribar a la secció del botó. Activa l'enllaç etiquetat “Start the Justícia i Equitat Challenge” per obrir el quadern interactiu en una pestanya nova.
