# %% [markdown]
# **Note:** This notebook is designed for **Google Colab**.
#
# If you see the Colab logo <span style='vertical-align:bottom;'><img src='https://colab.research.google.com/img/colab_favicon_256px.png' width='40' alt='Colab logo'></span> in the top-left corner, you're all set! Please **proceed to Section 1**.
#
# If you don't see the logo (e.g., you are on GitHub), please click the button below to open it in the correct environment:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mparrott-at-wiris/aimodelshare/blob/master/notebooks/Etica_en_Joc_Justice_Challenge.ipynb)

# %% [markdown]
# ---
# # **Sección 1: Bienvenido a Ética en Juego**

# %% [markdown]
# We live in a world where unseen algorithms are making decisions about our lives. We trust them to be **objective**. We trust them to be **fair**.
#
# But what if they're not?
#
# Bienvenido a **Ética en Juego**. Esto no es una conferencia tradicional. Esta es una misión práctica que te pone al mando de un potente sistema de IA. Creemos que la manera ideal de entender los complejos compromisos del mundo real en tecnología es experimentarlos por ti mismo.
#
# Hemos convertido la ética de la IA en un juego: gana insignias, toma decisiones de alto impacto y compite en una clasificación en vivo. Cada elección forma tu puntuación y tu sentido de justicia en la era de la IA.
#
# ---
#
# ## 🎯 **Tu misión**
#
# En este módulo, **El Reto de Justicia y Equidad**, te enfrentarás a uno de los mayores riesgos éticos en la IA hoy: **sesgo y equidad**.
#
# Tu viaje comenzará asumiendo dos roles del mundo real:
#
# 1.  **El Juez:** You’ll use an AI’s recommendations to decide who gets released from prison. But what happens if the algorithm is wrong?
# 2.  **El Ingeniero de IA:** You'll compete with others to build AI models that are much better at identifying criminal risk.  But better by whose definition?
#
# Through these roles, you’ll begin to discover how data, design, and human judgment intertwine to produce real-world consequences.
#
# ---
#
# ## 🧭 **La Brújula Moral**
#
# Tu objetivo cambiará: reconstruye tu modelo de IA, esta vez guiado por la **Puntuación de la Brújula Moral**, que premia la **mejora ética** por encima del rendimiento bruto.
#
# Siguiendo la guía experta del **Centro de Ética en IA OEIAC de la UdG**, competirás para detectar sesgo, medir la inequidad y rediseñar tu sistema hacia una mayor justicia.
#
# ---
#
# ## 💡 **Una herramienta para cada aprendiz**
#
# Esta plataforma está diseñada para una audiencia diversa:
#
# * **"Baja tecnología primero":** **No se requiere conocimiento previo de programación o IA.** Todas las interacciones principales utilizan botones y controles deslizantes simples.
# * **Doble camino:** Los estudiantes avanzados pueden utilizar **notebooks de código opcionales y paralelos** para construir y entrenar los modelos directamente.
#
# Este programa se alinea directamente con los objetivos educativos catalanes, españoles y de la UE para fomentar usuarios social y éticamente conscientes de la tecnología digital.
#
# ---

# %% [markdown]
# ## 🚀 **Guía de inicio rápido**
#
# Esta guía resume las acciones simples necesarias para comenzar el reto con éxito.
#
# **Lee estos pasos primero** y después práct icalos en la **Sección 2** a continuación.
#
# 1.  **Ejecutar la primera celda** (¿Cómo?):
#     * Encuentra el primer bloque con el ▶ **Botón de reproducción** al lado.
#     * **Haz clic en el $\blacktriangleright$ Botón de reproducción** y espera un momento.
#
# 2.  **Cambiar tu nombre** (Practicar una edición simple):
#     * Encuentra el segundo bloque con el ▶ **Botón de reproducción**.
#     * **Edita con cuidado el texto** dentro de las comillas (`""`) para reemplazar el nombre por defecto con el tuyo.
#     * **DEBES** hacer clic en el ▶ **Botón de reproducción again** to save and run the cell with your new name.
#
# 3.  **Instalar el software**:
#     * El siguiente paso te pedirá que instales el software necesario.
#     * **Haz clic en el ▶ Botón de reproducción** en la celda de instalación y espera a que se complete.
#
# 4.  **Lanzar tu primera aplicación**:
#     * Encuentra el final ▶  **Botón de reproducción** en la sección del tutorial.
#     * **Haz clic en el ▶ Botón de reproducción** y espera a que la aplicación se cargue.
#     * **Usa la aplicación:** Interactúa con el mini-sitio web que aparece para comenzar oficialmente el reto.
#
# ---
# ### Acción clave a recordar:
# La acción más importante para casi cada paso es **hacer clic en el ▶ Botón de reproducción** y después esperar a que aparezca la salida.

# %% [markdown]
# ---
# # **Sección 2: Tutorial de inicio rápido**

# %% [markdown]
# ## 🛑 Solución rápida de problemas: Cuando las cosas salen mal
#
# Don't panic\! Aquí tienes los tres problemas más comunes y sus soluciones. Lee esto primero para que sepas qué hacer si te bloqueas.
#
# | Problema | Causa | Solución |
# | :--- | :--- | :--- |
# | **"La celda gira indefinidamente\!"** | El notebook se desconectó de los recursos del ordenador. | Mira en la **esquina superior derecha**. Si dice **"Conectar,"** haz clic en ese botón para reconectar. |
# | **"Veo un mensaje de error rojo\!"** | Una celda más arriba en el notebook se saltó o no se ejecutó. | **Desplázate hacia arriba** y comprueba que *cada* celda de código sobre el error se haya ejecutado (busca el paréntesis numerado al lado de cada botón de reproducción, como `[1]`). |
# | **"He cambiado el texto pero no ha pasado nada\!"** | No has vuelto a ejecutar el código después de hacer una edición. | Después de editar información en una celda de código, **debes** hacer clic en el $\blacktriangleright$ **Botón de reproducción** nuevamente para utilizar la nueva información. |
#
# -----

# %% [markdown]
# ## Now, let's practice each step.

# %% [markdown]
# ## 1. **Run** your first code cell\!
#
# Your only job is **to place your cursor above the below code cell**, then to click the ▶ **Botón de reproducción** on the left side to run the code in the cell.
#
# **Note:** *A warning message may pop up because the notebook was not authored by Google, select "RUN ANYWAY".*

# %%
# CODE CELL 1: Click the Play button (circular arrow) to the left of this cell.
print("✅ Congratulations! You ran your first cell successfully.")
print("The new text below the cell is the 'output' of the code. The play button now shows a number like [1] next to it.")
print("You are ready to to practice the second quickstart step below!")

# %% [markdown]
# ### 2. **Cambiar tu nombre** (Practicar una edición simple)
#
# The only time you will need to type inside a Code Cell is when we ask you to change a specific piece of information.
#
# **Your Goal:**
#
# 1.  Find the text that says `"Your Name"` in the cell below.
# 2.  **Delete** it and type your actual name, keeping the quotes (`""`) around it.
# 3.  **Place your cursor above the below code cell**, then click the ▶ **Botón de reproducción** for the cell again to apply the change.

# %%
# CODE CELL 2: Change the text inside the quotes below and then run the cell.
user_name = "Your Name"

print("Hello, " + user_name + "! Let's practice launching an application next.")

# %% [markdown]
# ### 3. **Install the Application Software**
#
# Almost ready! The tutorial app is part of a special software package that we need to install first.
#
# **Your Task:**
# * Haz clic en el ▶ **Botón de reproducción** on the code cell below.
# * Wait for it to finish. You will see a message "✅ Installation complete!" when it's done.

# %%
# This cell installs the 'aimodelshare' library
print("Installing required libraries (Give this process 30 seconds or so)...")
# !pip install aimodelshare --upgrade -q --no-warn-script-location > /dev/null 2>&1
print("✅ Installation complete! You can now launch the app in the next step.")

# %% [markdown]
# ### 4. **Lanzar tu primera aplicación**
#
# Great! Now that the software is installed, you can launch the tutorial app.
#
# **Your Task:**
# * Haz clic en el ▶ **Botón de reproducción** on the final code cell below.
# * A small, interactive website window will appear below the cell.
# * Complete the tasks inside that app to finish the tutorial.

# %%
# This cell imports and runs the tutorial app
print("Loading tutorial app (in 15 seconds or so...)")
from aimodelshare.moral_compass.apps.tutorial import create_tutorial_app
tutorial_app = create_tutorial_app()
tutorial_app.launch(inline=True, share=False, debug=False, height=750, quiet=True)

# %% [markdown]
# ---
# # **Below content under active development please ignore!**

# %% [markdown]
# ---
# # **Section 3: The Justice and Equity Challenge**

# %% [markdown]
# Now you are ready to begin the challenge! The next few sections will guide you through an interactive experience where you'll make real ethical decisions.

# %% [markdown]
# ## **Part 1: You Be the Judge**
#
# In this first part of the challenge, you will take on the role of a judge. You'll review defendant profiles and decide whether to release them from prison or keep them incarcerated.
#
# An AI system will provide risk predictions to help guide your decisions. But remember: these are just predictions.
#
# **Your Task:**
# * Haz clic en el ▶ **Botón de reproducción** below to launch the "You Be the Judge" app.
# * Make your decisions for each defendant.
# * When finished, scroll down to continue to the next section.

# %%
# Launch the You Be the Judge app
print("Loading the Judge Decision App (in 15 seconds or so...)")
from aimodelshare.moral_compass.apps.judge import create_judge_app
judge_app = create_judge_app()
judge_app.launch(inline=True, share=False, debug=False, height=1200, quiet=True)

# %% [markdown]
# ## **Part 2: What If the AI Was Wrong?**
#
# You just made several important decisions based on AI predictions. But what happens when those predictions are incorrect?
#
# In this section, you'll learn about:
# * **False Positives** - When AI incorrectly predicts high risk
# * **False Negatives** - When AI incorrectly predicts low risk
# * The real-world consequences of each type of error
#
# **Your Task:**
# * Haz clic en el ▶ **Botón de reproducción** below to launch the interactive slideshow.
# * Read through each slide carefully.
# * When finished, scroll down to continue.

# %%
# Launch the AI Consequences app
print("Loading the AI Consequences slideshow (in 15 seconds or so...)")
from aimodelshare.moral_compass.apps.ai_consequences import create_ai_consequences_app
consequences_app = create_ai_consequences_app()
consequences_app.launch(inline=True, share=False, debug=False, height=1000, quiet=True)

# %% [markdown]
# ## **Part 3: So, What Is AI, Really?**
#
# Before you can build better AI systems, you need to understand what AI actually is and how it works.
#
# In this section, you'll learn:
# * A simple, non-technical definition of AI
# * How predictive models work (Input → Model → Output)
# * How this applies to the criminal justice scenario
# * Why understanding AI is crucial for building ethical systems
#
# **Your Task:**
# * Haz clic en el ▶ **Botón de reproducción** below to launch the interactive lesson.
# * Try out the interactive prediction demo.
# * When finished, you'll be ready to start building your own AI models!

# %%
# Launch the What Is AI app
print("Loading the What Is AI lesson (in 15 seconds or so...)")
from aimodelshare.moral_compass.apps.what_is_ai import create_what_is_ai_app
what_is_ai_app = create_what_is_ai_app()
what_is_ai_app.launch(inline=True, share=False, debug=False, height=1100, quiet=True)

# %% [markdown]
# ---
# # **Next Steps**
#
# Congratulations! You've completed the first part of the Ètica en Joc Justice Challenge.
#
# You now understand:
# * ✅ The stakes of using AI in criminal justice
# * ✅ The consequences of AI errors (false positives and false negatives)
# * ✅ What AI is and how it works
#
# In the next sections (coming soon), you'll:
# * Build your own AI models to predict criminal risk
# * Learn how to measure and reduce bias in AI systems
# * Compete on a leaderboard using the Moral Compass Score
# * Discover best practices for ethical AI deployment
#
# ---
#
# **Stay tuned for more!**
