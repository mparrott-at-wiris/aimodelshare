# %% [markdown]
# <div style="text-align:center; margin-top:40px;">
#   <h1 style="font-size:2.6em; font-weight:700; margin-bottom:0.4em;">Ética en Juego</h1>
#
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     Welcome to Ética en Juego! Experimentarás cómo la inteligencia artificial puede afectar decisiones del mundo real. Through immersive, gamified scenarios, you’ll take on roles, make choices, and see the consequences of AI in action—no technical background required.
#   </p>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     Tus acciones serán guiadas por la Brújula Moral, desarrollada con expertos del Observatorio Catalán de Ética en Inteligencia Artificial (OEIAC) de la UdG para medir cuán éticas son tus soluciones de IA.
#   </p>
#
#   <h2 style="font-size:2.0em; font-weight:600; margin-top:1.5em; color:#444;">You’ll tackle three challenges:</h2>
#   <ul style="font-size:1.2em; line-height:1.6; max-width:680px; margin:20px auto; text-align:left; list-style-position: inside;">
#     <li><strong>Justicia y Equidad</strong> – Identifica el sesgo y aprende cómo corregirlo en modelos de IA.</li>
#     <li><strong>Transparencia y Explicabilidad</strong> – Haz que las decisiones de IA sean comprensibles y responsables. (Próximamente)</li>
#     <li><strong>Sostenibilidad</strong> – Equilibra el impacto ambiental, la privacidad y la supervisión humana para crear IA responsable. (Próximamente)</li>
#   </ul>
#
#   <p style="font-size:1.0em; color:#555; max-width:700px; margin:30px auto 30px;">
#     Programa coordinado por Edutech Cluster, con el apoyo de la Generalitat de Catalunya.
#   </p>
#
#   <hr style="margin:50px auto; max-width:640px;">
#
#   <h2 style="font-size:2.0em; font-weight:600; margin-top:0; color:#444;">Justicia y Equidad Challenge</h2>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     This is the flagship module of the Ética en Juego program. Nuestro objetivo es sensibilizar sobre los riesgos éticos de la Inteligencia Artificial, no a través de teoría abstracta, sino a través de una experiencia de aprendizaje práctico.
#   </p>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     En este reto, tú:
#   </p>
#   <ul style="font-size:1.2em; line-height:1.6; max-width:680px; margin:20px auto; text-align:left; list-style-position: inside;">
#     <li>Asumirás roles del mundo real, como un juez que utiliza recomendaciones de IA y un ingeniero de IA que construye un nuevo modelo.</li>
#     <li>Interactuarás con un escenario gamificado basado en una IA del mundo real utilizada para predecir el riesgo criminal.</li>
#     <li>Descubrirás cómo centrarse solo en la precisión técnica puede crear resultados injustos y sesgados.</li>
#     <li>Aprenderás a identificar, medir y corregir el sesgo de la IA utilizando un marco ético experto.</li>
#   </ul>
#   <p style="font-size:1.3em; line-height:1.4; max-width:780px; margin:20px auto;">
#     La experiencia completa requiere aproximadamente entre 1 y 1,5 horas para completarse. Al final, recibirás un certificado de educación digital para reconocer tus nuevas habilidades.
#   </p>
#
#   <hr style="margin:50px auto; max-width:640px;">
#
#   <div style="margin:50px 0;">
#     <a href="https://colab.research.google.com/github/mparrott-at-wiris/aimodelshare/blob/master/notebooks/Etica_en_Joc_Justice_Challenge.ipynb" target="_blank" style="text-decoration:none;">
#       <div style="display:inline-block; background:#2962FF; color:#fff; padding:28px 46px; border-radius:14px; font-size:2.0em; font-weight:700; box-shadow:0 6px 18px rgba(0,0,0,0.25);">
#         ▶ Start the Justicia y Equidad Challenge
#       </div>
#     </a>
#   </div>
#   <p style="font-size:1.05em; color:#555; max-width:700px; margin:0 auto 40px;">
#     Después de hacer clic, se abrirá una nueva pestaña del navegador en Google Colab. Si aparece una advertencia, elige <em>“Ejecutar igualmente”</em>. Luego sigue los pasos simples que se muestran allí.
#   </p>
#   <hr style="margin:50px auto; max-width:640px;">
#   <p style="font-size:0.95em; color:#666; max-width:680px; margin:0 auto 60px;">
#     Si el botón no funciona, copia y pega este enlace en tu navegador:<br>
#     <code>https://colab.research.google.com/github/mparrott-at-wiris/aimodelshare/blob/master/notebooks/Etica_en_Joc_Justice_Challenge.ipynb</code>
#   </p>
# </div>

# %% [markdown]
# ### Accesibilidad / Texto para lectores de pantalla
# Utiliza la navegación por encabezados para llegar a la sección del botón. Activa el enlace etiquetado “Start the Justicia y Equidad Challenge” para abrir el cuaderno interactivo en una pestaña nueva.
